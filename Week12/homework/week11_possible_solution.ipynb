# %%
import pandas as pd
import random
from faker import Faker

class FakeDataGenerator:
    
    def __init__(self, df = None, rows=5):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` length
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!
          
        self.fake = Faker()
        
        if df is not None:
            self.df = df
            self.rows = len(df)
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [random.randint(small_value,high_value) for i in range(self.rows)]
        
        return self.df       
    
        
    def add_name(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.first_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.last_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.email() for i in range(self.rows)]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake phone number to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.phone_number() for i in range(self.rows)]
        
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake address to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.address() for i in range(self.rows)]
        
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_name('name')
fakeGen.add_last_name('lastname')
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
# Out:
#     product_id         name   lastname  \
# 0          123      Jessica    Ballard
# 1          124  Christopher     Jensen
# 2          125      Michael    Hancock
# 3          126      Chelsea       Kane
# 4          127     Samantha       Ruiz
# 5          128      Allison      Hurst
# 6          129      Tiffany  Carpenter
# 7          130         Jodi   Anderson
# 8          131       Joseph         Li
# 9          132     Kimberly    Garrett
# 10         133        Aaron     Guzman
# 11         134      Beverly       Long
# 12         135       Joshua      Smith
# 13         136     Patricia       Hill
# 14         137      Mallory   Campbell
# 15         138        Karen   Ferguson
# 16         139      Deborah     Curtis
# 17         140         Kyle     Walker
# 18         141        Kelly      Leach
# 19         142       Travis      Green
# 20         143      Krystal      Jones
# 21         144        Erica   Mccarthy
# 22         145         John       Bell
# 23         146       Alexis     Morton
# 24         147        Andre    Jackson
#
#                                      shipping_address  \
# 0       465 Katherine Mount\nJeffreyborough, LA 26557
# 1   861 Victoria Valleys Suite 742\nHubbardmouth, ...
# 2       938 Contreras Stravenue\nMillerstad, LA 16341
# 3           531 Lewis Mews\nChristopherview, MI 57871
# 4   8312 Katrina Branch Suite 619\nLake Sydneyburg...
# 5         72537 James Meadows\nPort Theresa, CA 87420
# 6                    Unit 6954 Box 8878\nDPO AP 10484
# 7   3245 Joseph Groves Suite 216\nNorth Rachel, VA...
# 8            48577 Kennedy Glen\nDixonmouth, NE 64434
# 9           527 Michael Gardens\nEast Brian, ND 68324
# 10  78164 Donald Keys Suite 468\nPort Joseph, MO 9...
# 11  31049 Ian Well Suite 965\nSouth Melissa, OK 73514
# 12   8496 Williams Mill Suite 953\nLucaston, WV 44328
# 13  95319 Baker Square Apt. 198\nDanielside, VT 03945
# 14        608 Lewis Ranch\nLake Williamport, IN 52218
# 15           392 Matthew Loaf\nEast Michael, OK 70321
# 16             834 John Island\nNorth Renee, VA 54065
# 17       16774 Pierce Burgs\nNew Danieltown, HI 63783
# 18        9942 Miller Motorway\nShannonfurt, IA 33299
# 19         3371 Daniel Glens\nRodriguezfort, IN 13909
# 20  0175 Tyler Common Suite 794\nSouth Lindseyshir...
# 21  18000 Brady Curve Suite 262\nPort Danielle, LA...
# 22  3679 Williams Path Apt. 649\nEllisville, NC 99830
# 23   464 Preston Square Apt. 129\nTerristad, DE 54392
# 24  6036 Scott Brooks Suite 297\nNew Brandonhaven,...
#
#                                       billing_address          customer_phone
# 0   783 Browning Hollow Suite 818\nWheelerborough,...    001-082-116-3792x989
# 1             84409 James Walk\nNew Brandon, MS 70442        447-996-0240x025
# 2   30083 Cameron Manors Suite 431\nKimberlymouth,...       (194)885-0165x025
# 3   4173 Mikayla Court Suite 358\nRichardton, UT 3...        385-554-0091x020
# 4                    Unit 3621 Box 8719\nDPO AA 24221           (589)667-9816
# 5   22620 Samantha Lane Apt. 113\nNorth Rachelvill...            338.618.7599
# 6                759 Lindsey Port\nEricfurt, UT 24147       050.443.8848x5746
# 7        74176 Susan Trail\nLake Lesliestad, HI 28233      970.159.0451x17662
# 8                    Unit 4878 Box 0686\nDPO AP 12638       065-352-4895x5895
# 9   01171 Rodriguez Courts Apt. 528\nEricksontown,...  001-250-876-8269x10025
# 10            0189 Deanna Road\nRachelshire, TX 98096  001-009-591-9806x73609
# 11         6232 Gilbert Divide\nNew Colleen, CO 39736    001-190-803-9751x365
# 12  12562 Floyd Shores Apt. 243\nSouth Robertmouth...              2658361181
# 13   260 Miller Wall Suite 902\nLake Adrian, PA 87616        001-492-812-7836
# 14             115 Duran Ferry\nLake Amanda, CA 67892            581-278-3916
# 15                           USNV Johns\nFPO AP 08866            820-151-1921
# 16    596 Todd Ranch Apt. 098\nLake Cynthia, MN 39689       235-655-7775x1909
# 17    227 James Light Suite 111\nHolmesfort, AK 72880    001-137-664-1021x494
# 18                   PSC 2545, Box 9685\nAPO AE 97268     (165)504-5882x41300
# 19  81572 Wells Ports Apt. 818\nEast Davidtown, OH...      792.020.1708x17460
# 20  2912 Scott Lakes Apt. 973\nEast Williamfurt, M...   001-999-493-9518x7495
# 21  06171 Marquez Fields Apt. 496\nNorth Carmen, C...        694-511-6429x437
# 22            8157 Melissa Hollow\nBellport, NV 62527            891.024.3200
# 23   8534 Brooks Tunnel Apt. 843\nNancyberg, OR 57452      332-847-6108x16610
# 24            3709 Roberts Lakes\nJaredfurt, WA 12118      302.630.0445x03218

# %%
# Case 2 - no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                     shipping_address  \
# 0              7399 Sarah Flat\nButlerbury, AK 54735
# 1        11683 Michael Valley\nEugeneburgh, TN 90366
# 2                          USCGC Moran\nFPO AA 71205
# 3       412 Sanchez Mall\nNew Nicholasland, CT 23395
# 4  1308 Vaughan Path Suite 664\nJoshuaside, ID 16305
#
#                                      billing_address          customer_phone  \
# 0                   Unit 0644 Box 2927\nDPO AE 54247      (635)419-6320x1061
# 1                           USS Porter\nFPO AE 56119    001-785-853-6788x557
# 2            705 Michael Key\nRobbinsmouth, MI 14201  001-182-489-0982x78799
# 3  0203 Garcia View Suite 109\nSouth Lauren, AL 1...    +1-521-486-1636x0619
# 4                  163 Bond Alley\nBellton, MA 47355              8068857157
#
#    sale_count
# 0          94
# 1          47
# 2          27
# 3          32
# 4          31
